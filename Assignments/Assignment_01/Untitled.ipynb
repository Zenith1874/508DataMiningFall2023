# %%
import pandas as pd 
df = pd.read_csv('Default-of-Credit-Card-Clients.csv')

# %%
df   # print the data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df.head(2)  # print the data in the first two rows
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
#
# [2 rows x 25 columns]

# %%
df.shape # (100, 6) 查看行数和列数
# Out:
# (30000, 25)

# %%
df.info() # 查看索引、数据类型和内存信息
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.describe() # 查看数值型列的汇总统计
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.dtypes # 查看各字段类型
# Out:
# ID                 int64
# LIMIT_BAL          int64
# SEX                int64
# EDUCATION          int64
# MARRIAGE           int64
# AGE                int64
# PAY_0              int64
# PAY_2              int64
# PAY_3              int64
# PAY_4              int64
# PAY_5              int64
# PAY_6              int64
# BILL_AMT1          int64
# BILL_AMT2          int64
# BILL_AMT3          int64
# BILL_AMT4          int64
# BILL_AMT5          int64
# BILL_AMT6          int64
# PAY_AMT1           int64
# PAY_AMT2           int64
# PAY_AMT3           int64
# PAY_AMT4           int64
# PAY_AMT5           int64
# PAY_AMT6           int64
# default_payment    int64
# dtype: object

# %%
df.axes # 显示数据行和列名
# Out:
# [RangeIndex(start=0, stop=30000, step=1),
#  Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#         'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#         'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#         'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#         'default_payment'],
#        dtype='object')]

# %%
df.columns # 列名
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default_payment'],
#       dtype='object')

# %%
df.EDUCATION.unique()
# Out:
# array([2, 1, 3, 5, 4, 6, 0], dtype=int64)

# %%
unique_values = df['EDUCATION'].unique()   #）计算并打印“教育”列的不同值

print(unique_values)
# Out:
# [2 1 3 5 4 6 0]

# %%
grouped_df = df.groupby('EDUCATION')['ID'].count()       ##）计算并打印“教育”列的不同值  求和
print(grouped_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 grouped_df = df.groupby('EDUCATION')['ID'].count()       ##）计算并打印“教育”列的不同值  求和
#       2 print(grouped_df)
#
# NameError: name 'df' is not defined

# %%
#(10 points) Calculate and print how many people have “default payment” = 1 and how many people have “default payment” = 0.
grouped_df = df.groupby('default_payment')['ID'].count()       ##）计算并打印“教育”列的不同值  求和
print(grouped_df)
# Out:
# default_payment
# 0    23364
# 1     6636
# Name: ID, dtype: int64

# %%
df = df.rename(columns={'default payment': 'default_payment'})
target_value0 = 1

target_value1 = 0
count_equal_to_target1 = (df['default_payment'] == target_value1).sum()
#(10 points) Calculate and print how many people have “default payment” = 1 and how many people have “default payment” = 0.
grouped_df = df.groupby('default_payment')['ID'].count()       ##）计算并打印“教育”列的不同值  求和
print(grouped_df)

count_equal_to_target0 = (df['default_payment'] == target_value0).sum()
print("Number of “default payment” = 1 equal to {}: {}".format(target_value0, count_equal_to_target1))
print("Number of “default payment” = 0 equal to {}: {}".format(target_value1, count_equal_to_target0))
# Out:
# default_payment
# 0    23364
# 1     6636
# Name: ID, dtype: int64
# Number of “default payment” = 1 equal to 1: 23364
# Number of “default payment” = 0 equal to 0: 6636

# %%
condition1 = df['MARRIAGE']  == 1
condition2 = df['default_payment']  == 1
count_with_conditions = (condition1 & condition2).sum()
print(" people who are married and have default payment = 1: {}".format(count_with_conditions))
# Out:
#  people who are married and have default payment = 1: 3206

# %%
condition1 = df['AGE']  > 30
condition2 = df['default_payment']  == 1
count_with_conditions = (condition1 & condition2).sum()
print(" people whose age is greater than 30 and have “default payment” = 1: {}".format(count_with_conditions))
# Out:
#  people whose age is greater than 30 and have “default payment” = 1: 4165

# %%
average_debt_male = df[df['SEX'] == 1]['LIMIT_BAL'].mean()
average_debt_female = df[df['SEX'] == 2]['LIMIT_BAL'].mean()
print("Average LIMIT_BAL for male:", average_debt_male)
print("Average LIMIT_BAL for female:", average_debt_female)
# Out:
# Average LIMIT_BAL for male: 163519.8250336474
# Average LIMIT_BAL for female: 170086.46201413427

# %%
average_debt_by_sex = df.groupby('SEX')['LIMIT_BAL'].mean()
print(average_debt_by_sex)
# Out:
# SEX
# 1    163519.825034
# 2    170086.462014
# Name: LIMIT_BAL, dtype: float64

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with columns X12 to X17
# If your columns are named differently, replace them accordingly

# List of column names for amount-of-bill-statement attributes
columns_to_analyze = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']

# Calculate the statistics for each column
statistics = df[columns_to_analyze].agg(['mean', 'std', 'min', 'max'])

# Display the calculated statistics
print(statistics)
# Out:
#           BILL_AMT1      BILL_AMT2     BILL_AMT3      BILL_AMT4  \
# mean   51223.330900   49179.075167  4.701315e+04   43262.948967
# std    73635.860576   71173.768783  6.934939e+04   64332.856134
# min  -165580.000000  -69777.000000 -1.572640e+05 -170000.000000
# max   964511.000000  983931.000000  1.664089e+06  891586.000000
#
#           BILL_AMT5      BILL_AMT6
# mean   40311.400967   38871.760400
# std    60797.155770   59554.107537
# min   -81334.000000 -339603.000000
# max   927171.000000  961664.000000

# %%
# 选择要计算协方差的列
columns_to_analyze =  ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']

# 使用Pandas的cov()函数计算协方差矩阵
covariance_matrix = df[columns_to_analyze].cov()

# 显示协方差矩阵
print("Covariance Matrix:")
print(covariance_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 columns_to_analyze =  ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
#       4 # 使用Pandas的cov()函数计算协方差矩阵
# ----> 5 covariance_matrix = df[columns_to_analyze].cov()
#       7 # 显示协方差矩阵
#       8 print("Covariance Matrix:")
#
# NameError: name 'df' is not defined

# %%
# 使用Pandas的corr()函数计算相关性矩阵
correlation_matrix = df[columns_to_analyze].corr()

# 显示相关性矩阵
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # 使用Pandas的corr()函数计算相关性矩阵
# ----> 2 correlation_matrix = df[columns_to_analyze].corr()
#       4 # 显示相关性矩阵
#       5 print("\nCorrelation Matrix:")
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with columns X12 to X17
# If your columns are named differently, replace them accordingly

# List of column names for quantitative attributes
columns_to_analyze = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
# Set the number of bins
num_bins = 5

# Create subplots for each attribute
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

# Flatten the axs array for easier iteration
axs = axs.flatten()

# Iterate through columns and create histograms
for i, column in enumerate(columns_to_analyze):
    ax = axs[i]
    ax.hist(df[column], bins=num_bins, color='blue', alpha=0.7)
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')
    ax.set_title(f'Histogram of {column}')

# Adjust subplot layout
plt.tight_layout()

# Show the histograms
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df' with columns X12 to X17
# If your columns are named differently, replace them accordingly

# List of column names for the attributes
columns_to_analyze =['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']

# Create a boxplot for each attribute
plt.figure(figsize=(12, 6))
plt.boxplot([df[column] for column in columns_to_analyze], labels=columns_to_analyze)
plt.xlabel('Attributes')
plt.ylabel('Values')
plt.title('Boxplot of Attribute Values')

# Show the boxplot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  # Optional, for enhanced visualizations

# Assuming you have a DataFrame named 'df' with columns X12 to X15
# If your columns are named differently, replace them accordingly

# List of column names for the selected attributes
attributes_to_analyze = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4']

# Create scatter plots for all possible attribute pairs
sns.set(style="ticks")  # Optional, for enhanced visualizations
sns.pairplot(df[attributes_to_analyze], kind="scatter", diag_kind="kde")

# Show the scatter plots
plt.show()
# Out:
# C:\Users\cui10\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\cui10\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\cui10\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\cui10\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame named 'df' with columns X12 to X15
# If your columns are named differently, replace them accordingly

# List of column names for the selected attributes
attributes_to_analyze = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4']

# Create scatter plots for all possible attribute pairs
sns.set(style="ticks")  # Optional, for enhanced visualizations
sns.pairplot(df[attributes_to_analyze], kind="scatter", diag_kind="kde")

# Show the scatter plots
plt.show()
# Out:
# C:\Users\cui10\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\cui10\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\cui10\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\cui10\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.api.types import CategoricalDtype

# Assuming you have a DataFrame named 'df' with columns X12 to X15
# If your columns are named differently, replace them accordingly

# List of column names for the selected attributes
attributes_to_analyze =  ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4']

# Create scatter plots for all possible attribute pairs
sns.set(style="ticks")  # Optional, for enhanced visualizations
sns.pairplot(df[attributes_to_analyze], kind="scatter", diag_kind="kde")

# Show the scatter plots
plt.show()
# Out:
# C:\Users\cui10\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\cui10\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\cui10\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\cui10\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import warnings
with warnings.catch_warnings():
    warnings.simplefilter(action='ignore', category=FutureWarning)
    # Warning-causing lines of code here

    import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have a DataFrame named 'df' with columns X12 to X15
# If your columns are named differently, replace them accordingly

# List of column names for the selected attributes
attributes_to_analyze = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4']

# Create scatter plots for all possible attribute pairs
sns.set(style="ticks")  # Optional, for enhanced visualizations
sns.pairplot(df[attributes_to_analyze], kind="scatter", diag_kind="kde")

# Show the scatter plots
plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Assuming you have a DataFrame named 'df' with the specified attributes
# If your columns are named differently, replace them accordingly

# List of columns to standardize
columns_to_standardize = ['LIMIT_BAL', 'AGE', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6','default payment next month']

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the selected columns
df[columns_to_standardize] = scaler.fit_transform(df[columns_to_standardize])

# Display the standardized DataFrame
print(df)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  PAY_0  PAY_2  \
# 0          1  -1.136720    2          2         1 -1.246020      2      2
# 1          2  -0.365981    2          2         2 -1.029047     -1      2
# 2          3  -0.597202    2          2         2 -0.161156      0      0
# 3          4  -0.905498    2          2         1  0.164303      0      0
# 4          5  -0.905498    1          2         1  2.334029     -1      0
# ...      ...        ...  ...        ...       ...       ...    ...    ...
# 29995  29996   0.404759    1          3         1  0.381275      0      0
# 29996  29997  -0.134759    1          3         2  0.815221     -1     -1
# 29997  29998  -1.059646    1          2         2  0.164303      4      3
# 29998  29999  -0.674276    1          3         1  0.598248      1     -1
# 29999  30000  -0.905498    1          2         1  1.140680      0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with your original data
# If your columns are named differently, replace them accordingly
df = pd.read_csv('Default-of-Credit-Card-Clients.csv')
# Shuffle the original DataFrame randomly
shuffled_df = df.sample(frac=1, random_state=42)  # 'random_state' for reproducibility

# Select the first 1000 rows as the random sample
sample_size = 1000
random_sample = shuffled_df.iloc[:sample_size]

# Display the random sample
print(random_sample)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 2308    2309      30000    1          2         2   25      0      0      0
# 22404  22405     150000    2          1         2   26      0      0      0
# 23397  23398      70000    2          3         1   32      0      0      0
# 25058  25059     130000    1          3         2   49      0      0      0
# 2664    2665      50000    2          2         2   36      0      0      0
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 1668    1669     100000    1          2         2   30     -2     -2     -2
# 24758  24759     100000    1          3         1   40      2      0      0
# 4336    4337     330000    2          2         1   39      8      7      6
# 15543  15544     180000    1          1         2   30      1     -2     -2
# 24409  24410      50000    1          1         1   37      0      0      0
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates

# Assuming you have a DataFrame named 'df' with your original data
# If your columns are named differently, replace them accordingly

# Separate the data into two subsets based on 'default' label
default_0 = df[df['default payment next month'] == 0]
default_1 = df[df['default payment next month'] == 1]

# Sample 500 instances from each subset without replacement
sample_size = 500
sample_default_0 = default_0.sample(n=sample_size, random_state=42)
sample_default_1 = default_1.sample(n=sample_size, random_state=42)

# Concatenate the two samples to create the balanced random sample
balanced_sample = pd.concat([sample_default_0, sample_default_1])

# Visualize the balanced sample using parallel coordinates

attributes_to_visualize = ['LIMIT_BAL', 'AGE', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6','default payment next month']

plt.figure(figsize=(12, 6))
parallel_coordinates(balanced_sample, 'default payment next month', colormap='viridis')

# Add a legend
plt.legend(title='Default', loc='upper right', labels=['0', '1'])

# Set labels and title
plt.xlabel('Attributes')
plt.ylabel('Attribute Values')
plt.title('Parallel Coordinates Visualization')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 假设您有一个名为 'df' 的 DataFrame 包含您的数据
# 如果列名不同，请相应地替换

# 选择要可视化的列
selected_columns = ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1']

# 创建一个包含所选列的新 DataFrame
selected_data = df[selected_columns]

# 使用 Pandas 的 hist() 方法创建直方图
selected_data.hist(bins=20, figsize=(12, 8))  # 调整 bins 和 figsize 根据需要

# 设置图标题和轴标签
plt.suptitle("Histograms of Selected Columns", fontsize=16)
plt.xlabel("Column Values", fontsize=14)
plt.ylabel("Frequency", fontsize=14)

# 显示图
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 假设您有一个名为 'df' 的 DataFrame 包含您的数据
# 如果列名不同，请相应地替换

# 选择要可视化的列
selected_columns = ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1']

# 设置子图的行和列数
num_rows = 4
num_cols = 3

# 创建一个新的图形
plt.figure(figsize=(15, 12))

# 使用循环逐个绘制每列的直方图
for i, column in enumerate(selected_columns, 1):
    plt.subplot(num_rows, num_cols, i)
    plt.hist(df[column], bins=20, edgecolor='k')
    plt.xlabel(column, fontsize=12)
    plt.ylabel('Frequency', fontsize=12)
    plt.title(f'Histogram of {column}', fontsize=14)

# 调整子图之间的间距
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sns

# Assuming you have a DataFrame named 'df' with your original data
# If your columns are named differently, replace them accordingly

# Step 1: Create a random sample from the original data
sample_size = 1000
random_sample = df.sample(n=sample_size, random_state=42)

# Step 2: Separate the labels from the data
labels = random_sample['default payment next month']
data = random_sample.drop(columns=['default payment next month'])

# Step 3: Perform PCA to reduce dimensionality to 2
pca = PCA(n_components=2)
pca_result = pca.fit_transform(data)

# Step 4: Create a scatterplot with labels
plt.figure(figsize=(10, 6))
sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=labels, palette=sns.color_palette("hsv", as_cmap=True))

# Add a legend
plt.legend(title='Default Payment', loc='upper right', labels=['Not Default', 'Default'])

# Set labels and title
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Scatterplot (2D Projection)')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 23
#      21 # Step 4: Create a scatterplot with labels
#      22 plt.figure(figsize=(10, 6))
# ---> 23 sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=labels, palette=sns.color_palette("hsv", as_cmap=True))
#      25 # Add a legend
#      26 plt.legend(title='Default Payment', loc='upper right', labels=['Not Default', 'Default'])
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:744, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     741 variables = _ScatterPlotter.get_semantics(locals())
#     742 p = _ScatterPlotter(data=data, variables=variables, legend=legend)
# --> 744 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sns

# Assuming you have a DataFrame named 'df' with your original data
# If your columns are named differently, replace them accordingly

# Step 1: Create a random sample from the original data
sample_size = 1000
random_sample = df.sample(n=sample_size, random_state=42)

# Step 2: Separate the labels from the data
labels = random_sample['default payment next month']
data = random_sample.drop(columns=['default payment next month'])

# Step 3: Perform PCA to reduce dimensionality to 2
pca = PCA(n_components=2)
pca_result = pca.fit_transform(data)

# Step 4: Create a scatterplot with labels
plt.figure(figsize=(10, 6))
sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=labels, palette='viridis')  # Modify the palette here

# Add a legend
plt.legend(title='Default Payment', loc='upper right', labels=['Not Default', 'Default'])

# Set labels and title
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Scatterplot (2D Projection)')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sns

# Assuming you have a DataFrame named 'df' with your original data
# If your columns are named differently, replace them accordingly

# Step 1: Create a random sample from the original data
sample_size = 1000
random_sample = df.sample(n=sample_size, random_state=42)

# Step 2: Separate the labels from the data
labels = random_sample['default payment next month']
data = random_sample.drop(columns=['default payment next month'])

# Step 3: Perform PCA to reduce dimensionality to 2
pca = PCA(n_components=2)
pca_result = pca.fit_transform(data)

# Step 4: Create a scatterplot with labels
plt.figure(figsize=(10, 6))
sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=labels, palette='coolwarm')  # Use a different palette here

# Add a legend
plt.legend(title='Default Payment', loc='upper right', labels=['Not Default', 'Default'])

# Set labels and title
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Scatterplot (2D Projection)')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sns

# Assuming you have a DataFrame named 'df' with your original data
# If your columns are named differently, replace them accordingly

# Step 1: Create a random sample from the original data
sample_size = 1000
random_sample = df.sample(n=sample_size, random_state=42)

# Step 2: Separate the labels from the data
labels = random_sample['default payment next month']
data = random_sample.drop(columns=['default payment next month'])


# Step 3: Perform PCA to reduce dimensionality to 2
pca = PCA(n_components=2)
pca_result = pca.fit_transform(data)

# Step 4: Create a scatterplot with labels
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=labels, palette='coolwarm')

# Custom legend labels and colors
legend_labels = ['Not Default', 'Default']
legend_colors = scatter.get_legend().legendHandles

# Create the legend with custom labels and colors
plt.legend(legend_colors, legend_labels, title='Default Payment', loc='upper right')

# Set labels and title
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Scatterplot (2D Projection)')

# Show the plot
plt.show()
# Out:
# C:\Users\cui10\AppData\Local\Temp\ipykernel_37088\2104289125.py:28: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   legend_colors = scatter.get_legend().legendHandles

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import seaborn as sns

# Assuming you have a DataFrame named 'df' with your original data
# If your columns are named differently, replace them accordingly

# Step 1: Create a random sample from the original data
sample_size = 1000
random_sample = df.sample(n=sample_size, random_state=42)

# Step 2: Separate the labels from the data
labels = random_sample['default payment next month']
data = random_sample.drop(columns=['default payment next month'])


# Step 3: Perform PCA to reduce dimensionality to 2
pca = PCA(n_components=2)
pca_result = pca.fit_transform(data)

# Step 4: Create a scatterplot with labels
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=labels, palette='coolwarm')

# Custom legend labels and colors
legend_labels = ['Not Default', 'Default']

# Get legend handles and labels
legend_handles, _ = scatter.get_legend_handles_labels()

# Create the legend with custom labels and handles
plt.legend(legend_handles, legend_labels, title='Default Payment', loc='upper right')

# Set labels and title
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Scatterplot (2D Projection)')

# Show the plot
plt.show()

# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# 加载原始数据
data = np.loadtxt('original_data.csv', delimiter=',')

# 生成随机样本
sample = data[np.random.randint(0, data.shape[0], size=1000)]

# 初始化 PCA 模型
pca = PCA(n_components=2)

# 对数据样本进行降维
projected_values = pca.fit_transform(sample)

# 设置标签
labels = data[:1000, -1]

# 绘制散点图
plt.scatter(projected_values[:, 0], projected_values[:, 1], c=labels)

# 添加标题和图例
plt.title('PCA Visualization')
plt.legend(labels)

# 显示图表
plt.show()
